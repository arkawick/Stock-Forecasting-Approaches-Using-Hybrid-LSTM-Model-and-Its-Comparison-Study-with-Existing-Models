# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# For reading stock data from yahoo
from pandas_datareader.data import DataReader

# For time stamps
from datetime import datetime

# %%
################# For Semester 7 #####################
######################################################
data = {'Bidirectional LSTM':4.2804146983621445, 
        'LSTM without Dropout':3.5622059039471754, 
        'LSTM with Dropout':7.246851101826089,
        'Linear Regression':8.9,
        'Dense forecast':14.4141,
        '5-day SMA':6.8635,
        '20-day SMA':16.6689}
algo = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (15, 5))
# creating the bar plot
plt.bar(algo, values, color ='blue',width = 0.2)
 
plt.xlabel("Algorithm used")
plt.ylabel("RMSE")
plt.title("Result Analysis of of All Models")
plt.show()

# %%
################# For Semester 8 #####################
######################################################

# %%
#For Traditional Machine Learning Methods
data = {'Linear regression':8.9, 
        'Logistic regression':8.012, 
        'K-Nearest Neighbor (KNN)':29.069,
        'Gaussian Naïve Bayes':11.07
        }
algo = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (15, 5))
# creating the bar plot
plt.bar(algo, values, color ='blue',width = 0.2)
 
plt.xlabel("Algorithm used")
plt.ylabel("RMSE")
plt.title("Result Analysis of Traditional Machine Learning Methods")
plt.show()

# %%
#For Time Series Analysis Methods
data = {'5-day SMA':6.8635,
        '10-day SMA':16.6689,
        '20-day SMA':26.54196, 
        'ARIMA':11.12, 
        'Prophet':14.408
        }
algo = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (15, 5))
# creating the bar plot
plt.bar(algo, values, color ='blue',width = 0.2)
 
plt.xlabel("Algorithm used")
plt.ylabel("RMSE")
plt.title("Result Analysis of Time Series Analysis Methods")
plt.show()

# %%
#For	Deep Learning and Neural Networks
data = {'Dense layer Forecast ':14.4141,
        'Simple Recurrent Neural Network (RNN)':6.8712,
        'Convolutional Neural Network (CNN)':6.0812, 
        'Gated Recurrent Unit (GRU)':5.96762, 
        'LSTM (with 2 LSTM layers without Dropout)':3.36544
        }
algo = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (15, 5))
# creating the bar plot
plt.bar(algo, values, color ='blue',width = 0.2)
 
plt.xlabel("Algorithm used")
plt.ylabel("RMSE")
plt.title("Result Analysis of Deep Learning and Neural Networks")
plt.show()

# %%
#LSTM is the best model so far in these three broad catagories of Algorithms

#So in the next comparisons Varients of LSTM, BiLSTM & Hybrid LSTMs are discussed

#For Varients of LSTM, BiLSTM & Hybrid LSTMs
data = {'LSTM(L-50,50,50|D-1)':16.168,
        'LSTM(L-50,50,50|D-25,1)':11.169778,
        'LSTM(L-50,50|D-25,1)':2.9759,
        'LSTM(L-128,64|D-25,1)':3.3644,
        'LSTM(L-256,128,64|D-25,1)':3.59565,
        'LSTM((L-100,d-0.2)*5|D-1)':4.50203,
        'LSTM((L-100,d-0.2)*4|D-1)':6.25669,
        'LSTM((L-100,d-0.2)*3|D-1)':5.35838
        }
algo = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (18, 5))
# creating the bar plot
plt.bar(algo, values, color ='blue',width = 0.2)
 
plt.xlabel("Algorithm used")
plt.ylabel("RMSE")
plt.title("Result Analysis of Varients of LSTM")
plt.show()

# %%
data = {'BiLSTM(B-256|D-25,1)':10.3486,
        'BiLSTM(B-128|D-25,1)':8.12783,
        'BiLSTM(B-128,64,d-0.5|D-25,1)':3.286326,
        'BiLSTM(B-128,64,32|D-25,1)':3.276113
        }
algo = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (15, 5))
# creating the bar plot
plt.bar(algo, values, color ='blue',width = 0.2)
 
plt.xlabel("Algorithm used")
plt.ylabel("RMSE")
plt.title("Result Analysis of Varients of BiLSTM ")
plt.show()

# %%
data = {'LSTM(L-50,50|D-25,1)':2.9759,
        'BiLSTM(L-128,64,32|D-25,1)':3.276113,
        'Hybrid LSTM(C-32|L-32,32|D-1)':3.5956,
        'Hybrid LSTM(C-64,128,64|(L-100,d-0.2)*2|D-1)':2.28643,
        'Hybrid LSTM(C-64,128,64|(B-100,d-0.2)*2|D-1)':2.2956
        }
algo = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (18, 5))
# creating the bar plot
plt.bar(algo, values, color ='blue',width = 0.2)
 
plt.xlabel("Algorithm used")
plt.ylabel("RMSE")
plt.title("Result Analysis of Varients of LSTM, BiLSTM with respect to Hybrid LSTMs")
plt.show()

# %%
print("""
Legend: L - LSTM Layers, B - BiLSTM Layers, D - Dense Layers, d - Dropout Layers, C - CNN Layers
""")
# Out:
# Legend: L - LSTM Layers, B - BiLSTM Layers, D - Dense Layers, d - Dropout Layers, C - CNN Layers
